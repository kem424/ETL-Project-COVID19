# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
oil_pruduction_df=pd.read_excel('Resources/oil_production.xlsx', index_col=0)
stock_df=pd.read_excel('Resources/stocks.xlsx', index_col=0)
imports_df=pd.read_excel('Resources/imports.xlsx', index_col=0)
export_df=pd.read_excel('Resources/export.xlsx', index_col=0)
us_refiner_cost_df=pd.read_excel('Resources/US_refiner.xlsx', index_col=0)
retail_prices_df=pd.read_excel('Resources/retail_prices.xlsx')

# %%
merge_table_oil_v_stock = pd.merge(oil_pruduction_df, stock_df,  on="Date")
merge_table_oil_v_stock
# Out:
#               Weekly U.S. Field Production of Crude Oil  (Thousand Barrels per Day)  \
# Date
# Jan 07, 1983                                               8634
# Jan 14, 1983                                               8634
# Jan 21, 1983                                               8634
# Jan 28, 1983                                               8634
# Feb 04, 1983                                               8660
# ...                                                         ...
# Mar 20, 2020                                              13000
# Mar 27, 2020                                              13000
# Apr 03, 2020                                              12400
# Apr 10, 2020                                              12300
# Apr 17, 2020                                              12200
#
#               Weekly U.S. Ending Stocks of Crude Oil and Petroleum Products  (Thousand Barrels)  \
# Date
# Jan 07, 1983                                                NaN
# ...

# %%
merge_table_oil_v_stock.columns
# Out:
# Index(['Weekly U.S. Field Production of Crude Oil  (Thousand Barrels per Day)',
#        'Weekly U.S. Ending Stocks of Crude Oil and Petroleum Products  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks excluding SPR of Crude Oil and Petroleum Products  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks of Crude Oil  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks excluding SPR of Crude Oil  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks excluding SPR and including Lease Stock of Crude Oil  (Thousand Barrels)',
#        'Weekly U.S. Crude Oil Stocks in Transit (on Ships) from Alaska  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks of Crude Oil in SPR  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks of Total Gasoline  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks of Finished Motor Gasoline  (Thousand Barrels)',
#        'Weekly U.S. Ending Stocks of Reformulated Motor Gasoline  (Thousand Barrels)',
# ...

# %%
oil_v_stock = merge_table_oil_v_stock[['Weekly U.S. Field Production of Crude Oil  (Thousand Barrels per Day)', 'Weekly U.S. Ending Stocks of Crude Oil  (Thousand Barrels)']]
oil_v_stock.tail(30)
# Out:
#               Weekly U.S. Field Production of Crude Oil  (Thousand Barrels per Day)  \
# Date
# Sep 27, 2019                                              12400
# Oct 04, 2019                                              12600
# Oct 11, 2019                                              12600
# Oct 18, 2019                                              12600
# Oct 25, 2019                                              12600
# Nov 01, 2019                                              12600
# Nov 08, 2019                                              12800
# Nov 15, 2019                                              12800
# Nov 22, 2019                                              12900
# Nov 29, 2019                                              12900
# Dec 06, 2019                                              12800
# Dec 13, 2019                                              12800
# Dec 20, 2019                                              12900
# ...

# %%
renamed_df_Cost_Refiners = us_refiner_cost_df.rename(columns={'U.S. Crude Oil Composite Acquisition Cost by Refiners (Dollars per Barrel)':"U.S. Crude Oil Composite Acquisition Cost by Refiners",
                                                             'U.S. Crude Oil Domestic Acquisition Cost by Refiners (Dollars per Barrel)':"U.S. Crude Oil Domestic Acquisition Cost by Refiners",
                                                              'U.S. Crude Oil Imported Acquisition Cost by Refiners (Dollars per Barrel)':"U.S. Crude Oil Imported Acquisition Cost by Refiners"})
renamed_df_Cost_Refiners.tail(10)
# Out:
#             U.S. Crude Oil Composite Acquisition Cost by Refiners  \
# Date
# 2019-05-01                                              65.11
# 2019-06-01                                              59.16
# 2019-07-01                                              60.53
# 2019-08-01                                              56.90
# 2019-09-01                                              58.60
# 2019-10-01                                              55.86
# 2019-11-01                                              57.88
# 2019-12-01                                              60.27
# 2020-01-01                                              57.94
# 2020-02-01                                              52.02
#
#             U.S. Crude Oil Domestic Acquisition Cost by Refiners  \
# Date
# 2019-05-01                                              65.17
# 2019-06-01                                              59.81
# 2019-07-01                                              61.47
# ...

# %%
US_Retail_Price_df = retail_prices_df.dropna(how='any')
US_States_Retail_Price = US_Retail_Price_df[['Date','Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                             'Weekly Colorado Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                             'Weekly Florida Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                             'Weekly New York Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                            'Weekly Minnesota Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                               'Weekly Ohio Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                               'Weekly Texas Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)',
                                               'Weekly Washington Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)']]
                                             
                                            
                                            
US_States_Retail_Price_rename = US_States_Retail_Price.rename(columns={'Date':'date','Weekly U.S. Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Weekly U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)",
                                             'Weekly Colorado Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Colorado",
                                             'Weekly Florida Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Florida",
                                             'Weekly New York Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"New York",
                                            'Weekly Minnesota Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Minnesota",
                                               'Weekly Ohio Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Ohio",
                                               'Weekly Texas Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Texas",
                                               'Weekly Washington Regular Conventional Retail Gasoline Prices  (Dollars per Gallon)':"Washington"})
US_States_Retail_Price_rename.tail(20)
# Out:
#               date  \
# 1529  Dec 09, 2019
# 1530  Dec 16, 2019
# 1531  Dec 23, 2019
# 1532  Dec 30, 2019
# 1533  Jan 06, 2020
# 1534  Jan 13, 2020
# 1535  Jan 20, 2020
# 1536  Jan 27, 2020
# 1537  Feb 03, 2020
# 1538  Feb 10, 2020
# 1539  Feb 17, 2020
# 1540  Feb 24, 2020
# 1541  Mar 02, 2020
# 1542  Mar 09, 2020
# 1543  Mar 16, 2020
# 1544  Mar 23, 2020
# 1545  Mar 30, 2020
# 1546  Apr 06, 2020
# 1547  Apr 13, 2020
# 1548  Apr 20, 2020
#
#       Weekly U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)  \
# 1529                                              2.478
# 1530                                              2.448
# 1531                                              2.447
# 1532                                              2.488
# 1533                                              2.494
# 1534                                              2.482
# 1535                                              2.448
# 1536                                              2.412
# ...

# %%
States = ["Colorado","Florida","New York","Minnesota","Ohio","Texas","Washington"]
states_dict = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut",
          "DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana",
          "IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts",
          "MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada",
          "NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota",
          "OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina",
          "SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington",
          "WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}

state_2 = {state: abbrev for abbrev, state in states_dict.items()}

state_2
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
# ...

# %%
# conntecting to DB
connection_string = "postgres:postgres@localhost:5432/covid19_db"
engine = create_engine(f'postgresql://{connection_string}')

#retrieve existing tables
engine.table_names()
# Out:
# ['us_states_cases',
#  'state',
#  'country',
#  'index_prices',
#  'country_cases',
#  'us_unemployment_stats',
#  'gas_price',
#  'hospital_beds']

# %%
for state in States:
    df = pd.DataFrame({'date':US_States_Retail_Price_rename["date"],
                       "state":state,
                        "avg_national":US_States_Retail_Price_rename["Weekly U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)"],
                        "state_price":US_States_Retail_Price_rename[state] })
    df['state_id'] = df["state"].map(state_2)
    #Use pandas to load csv converted DataFrame into database
    df.to_sql(name='gas_price', con=engine, if_exists='append', index=False)
                            
                        
df.tail()
# Out:
#               date       state  avg_national  state_price state_id
# 1544  Mar 23, 2020  Washington         2.007        2.696       WA
# 1545  Mar 30, 2020  Washington         1.886        2.575       WA
# 1546  Apr 06, 2020  Washington         1.800        2.483       WA
# 1547  Apr 13, 2020  Washington         1.735        2.407       WA
# 1548  Apr 20, 2020  Washington         1.694        2.310       WA

# %%
# read data from teable
pd.read_sql_query('select * from gas_price', con=engine).head()
# Out:
#            date     state  avg_national  state_price state_id
# 0  May 26, 2003  Colorado         1.439        1.477       CO
# 1  Jun 02, 2003  Colorado         1.428        1.455       CO
# 2  Jun 09, 2003  Colorado         1.456        1.444       CO
# 3  Jun 16, 2003  Colorado         1.480        1.496       CO
# 4  Jun 23, 2003  Colorado         1.451        1.490       CO

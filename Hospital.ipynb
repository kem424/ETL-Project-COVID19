# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
hospital_df=pd.read_csv('Resources/hospital_beds_global_regional_v1.csv')

# %%
hospital_df.head()
# Out:
#   country state county    lat   lng   type  measure   beds  population  year  \
# 0      AD   NaN    NaN  42.50   1.5    ICU  1000HAB  0.071       83747  2011
# 1      AD   NaN    NaN  42.50   1.5  TOTAL  1000HAB  2.500       84463  2009
# 2      AE   NaN    NaN  24.00  54.0  TOTAL  1000HAB  1.200     9197910  2013
# 3      AF   NaN    NaN  33.00  65.0  TOTAL  1000HAB  0.500    34413603  2015
# 4      AG   NaN    NaN  17.05 -61.8  TOTAL  1000HAB  3.800       92562  2014
#
#         source                                         source_url
# 0  icm-journal  https://link.springer.com/article/10.1007/s001...
# 1          wdi  https://data.worldbank.org/indicator/SH.MED.BE...
# 2          wdi  https://data.worldbank.org/indicator/SH.MED.BE...
# 3          wdi  https://data.worldbank.org/indicator/SH.MED.BE...
# 4          wdi  https://data.worldbank.org/indicator/SH.MED.BE...

# %%
reduced_hospital=hospital_df[['country','state','county','type','beds','measure','population','year','source']]
reduced_hospital.head()
# Out:
#   country state county   type   beds  measure  population  year       source
# 0      AD   NaN    NaN    ICU  0.071  1000HAB       83747  2011  icm-journal
# 1      AD   NaN    NaN  TOTAL  2.500  1000HAB       84463  2009          wdi
# 2      AE   NaN    NaN  TOTAL  1.200  1000HAB     9197910  2013          wdi
# 3      AF   NaN    NaN  TOTAL  0.500  1000HAB    34413603  2015          wdi
# 4      AG   NaN    NaN  TOTAL  3.800  1000HAB       92562  2014          wdi

# %%
us_hospital=reduced_hospital.loc[(reduced_hospital['year']==2019)&(reduced_hospital['country'] == 'US')]

us_hospital
# Out:
#      country state          county         type      beds  measure  \
# 469       US    AK  aleutians east          ICU  0.000000  1000HAB
# 470       US    AK  aleutians west          ICU  0.000000  1000HAB
# 472       US    AK       anchorage          ICU  0.244782  1000HAB
# 473       US    AK       anchorage        OTHER  0.191131  1000HAB
# 476       US    AK     bristol bay          ICU  0.000000  1000HAB
# ...      ...   ...             ...          ...       ...      ...
# 6178      US    WY           uinta          ICU  0.289045  1000HAB
# 6182      US   NaN             NaN        ACUTE  2.487640  1000HAB
# 6183      US   NaN             NaN          ICU  0.302904  1000HAB
# 6184      US   NaN             NaN        OTHER  0.242003  1000HAB
# 6185      US   NaN             NaN  PSYCHIATRIC  0.219750  1000HAB
#
#       population  year  source
# 469         3338  2019     khn
# 470         5784  2019     khn
# 472       298225  2019     khn
# 473       298225  2019  arcgis
# 476          917  2019     khn
# ...          ...   ...     ...
# 6178       20758  2019     khn
# 6182   328004407  2019   argis
# 6183   328004407  2019   argis
# 6184   328004407  2019   argis
# 6185   328004407  2019   argis
#
# [2332 rows x 9 columns]

# %%
us_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2332 entries, 469 to 6185
# Data columns (total 9 columns):
# country       2332 non-null object
# state         2328 non-null object
# county        2328 non-null object
# type          2332 non-null object
# beds          2332 non-null float64
# measure       2332 non-null object
# population    2332 non-null int64
# year          2332 non-null int64
# source        2332 non-null object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 182.2+ KB

# %%
us_hospital = us_hospital.dropna(how='any')

# %%
us_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2328 entries, 469 to 6178
# Data columns (total 9 columns):
# country       2328 non-null object
# state         2328 non-null object
# county        2328 non-null object
# type          2328 non-null object
# beds          2328 non-null float64
# measure       2328 non-null object
# population    2328 non-null int64
# year          2328 non-null int64
# source        2328 non-null object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 181.9+ KB

# %%
duplicate_h = us_hospital[us_hospital.duplicated(['state','type','beds','source'])]
duplicate_h
# Out:
#      country state          county type  beds  measure  population  year  \
# 470       US    AK  aleutians west  ICU   0.0  1000HAB        5784  2019
# 476       US    AK     bristol bay  ICU   0.0  1000HAB         917  2019
# 477       US    AK          denali  ICU   0.0  1000HAB        2303  2019
# 481       US    AK          haines  ICU   0.0  1000HAB        2537  2019
# 482       US    AK   hoonah-angoon  ICU   0.0  1000HAB        2146  2019
# ...      ...   ...             ...  ...   ...      ...         ...   ...
# 6130      US    WV         ritchie  ICU   0.0  1000HAB       10005  2019
# 6134      US    WV          tucker  ICU   0.0  1000HAB        7035  2019
# 6137      US    WV           wayne  ICU   0.0  1000HAB       41063  2019
# 6141      US    WV            wirt  ICU   0.0  1000HAB        5800  2019
# 6145      US    WV         wyoming  ICU   0.0  1000HAB       22130  2019
#
#      source
# 470     khn
# 476     khn
# 477     khn
# 481     khn
# 482     khn
# ...     ...
# 6130    khn
# 6134    khn
# 6137    khn
# 6141    khn
# 6145    khn
#
# [971 rows x 9 columns]

# %%
final_hospital=us_hospital[['state','type','beds']]

# %%
final_hospital.head()
# Out:
#     state   type      beds
# 469    AK    ICU  0.000000
# 470    AK    ICU  0.000000
# 472    AK    ICU  0.244782
# 473    AK  OTHER  0.191131
# 476    AK    ICU  0.000000

# %%
hospitals=final_hospital.groupby(['state']).sum()
hospitals.head()
# Out:
#             beds
# state
# AK      4.789014
# AL     11.967593
# AR      8.403947
# AZ      2.050268
# CA      8.182707

# %%
# conntecting to DB
connection_string = "postgres:postgres@localhost:5432/covid19_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#retrieve existing tables
engine.table_names()
# Out:
# ['state',
#  'country',
#  'index_prices',
#  'country_cases',
#  'us_unemployment_stats',
#  'hospital_beds',
#  'gas_price',
#  'us_states_cases']

# %%
#Use pandas to load csv converted DataFrame into database
hospitals.to_sql(name='hospital_beds', con=engine, if_exists='replace', index=True)

# %%
# read data from teable
pd.read_sql_query('select * from hospital_beds', con=engine).head()
# Out:
#   state       beds
# 0    AK   4.789014
# 1    AL  11.967593
# 2    AR   8.403947
# 3    AZ   2.050268
# 4    CA   8.182707
